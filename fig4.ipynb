# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

# %%
MS1_pS1_IM_10min = pd.read_csv('MS1_pS1_IM_10min.xls', sep = '\t')
MS1_pS1_IM_21min = pd.read_csv('MS1_pS1_IM_21min.xls', sep = '\t')
MS1_pS1_IM_60min = pd.read_csv('MS1_pS1_IM_60min.xls', sep = '\t')
MS1_pS1_XIC_10min = pd.read_csv('MS1_pS1_XIC_10min.xls', sep = '\t')
MS1_pS1_XIC_21min = pd.read_csv('MS1_pS1_XIC_21min.xls', sep = '\t')
MS1_pS1_XIC_60min = pd.read_csv('MS1_pS1_XIC_60min.xls', sep = '\t')
MS1_pS2_IM_10min = pd.read_csv('MS1_pS2_IM_10min.xls', sep = '\t')
MS1_pS2_IM_21min = pd.read_csv('MS1_pS2_IM_21min.xls', sep = '\t')
MS1_pS2_IM_60min = pd.read_csv('MS1_pS2_IM_60min.xls', sep = '\t')
MS1_pS2_XIC_10min = pd.read_csv('MS1_pS2_XIC_10min.xls', sep = '\t')
MS1_pS2_XIC_21min = pd.read_csv('MS1_pS2_XIC_21min.xls', sep = '\t')
MS1_pS2_XIC_60min = pd.read_csv('MS1_pS2_XIC_60min.xls', sep = '\t')

# %%
MS1_pS1_IM_10min = MS1_pS1_IM_10min[(MS1_pS1_IM_10min.iloc[:,0] >= 0.96)&(MS1_pS1_IM_10min.iloc[:,0]<=1.08)]
MS1_pS1_IM_10min = MS1_pS1_IM_10min.iloc[:,[0,1,3,5]]
MS1_pS1_IM_10min.columns = ['Time','M','M+1','M+2']
MS1_pS1_IM_10min = MS1_pS1_IM_10min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS1_IM_10min = MS1_pS1_IM_10min - np.amin(MS1_pS1_IM_10min.min().tolist())
#MS1_pS1_IM_10min = MS1_pS1_IM_10min/np.amax(MS1_pS1_IM_10min.max().tolist())
#MS1_pS1_IM_10min.iloc[0,:] = 0
#MS1_pS1_IM_10min.iloc[-1,:] = 0

MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()

# %%
MS1_pS1_IM_21min = MS1_pS1_IM_21min[(MS1_pS1_IM_21min.iloc[:,0] >= 0.96)&(MS1_pS1_IM_21min.iloc[:,0]<=1.08)]
MS1_pS1_IM_21min = MS1_pS1_IM_21min.iloc[:,[0,1,3,5]]
MS1_pS1_IM_21min.columns = ['Time','M','M+1','M+2']
MS1_pS1_IM_21min = MS1_pS1_IM_21min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS1_IM_21min = MS1_pS1_IM_21min - np.amin(MS1_pS1_IM_21min.min().tolist())
#MS1_pS1_IM_21min = MS1_pS1_IM_21min/np.amax(MS1_pS1_IM_21min.max().tolist())
#MS1_pS1_IM_21min.iloc[0,:] = 0
#MS1_pS1_IM_21min.iloc[-1,:] = 0
MS1_pS1_IM_21min = MS1_pS1_IM_21min.reset_index()

# %%
MS1_pS1_IM_60min = MS1_pS1_IM_60min[(MS1_pS1_IM_60min.iloc[:,0] >= 0.96)&(MS1_pS1_IM_60min.iloc[:,0]<=1.08)]
MS1_pS1_IM_60min = MS1_pS1_IM_60min.iloc[:,[0,1,3,5]]
MS1_pS1_IM_60min.columns = ['Time','M','M+1','M+2']
MS1_pS1_IM_60min = MS1_pS1_IM_60min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS1_IM_60min = MS1_pS1_IM_60min - np.amin(MS1_pS1_IM_60min.min().tolist())
#MS1_pS1_IM_60min = MS1_pS1_IM_60min/np.amax(MS1_pS1_IM_60min.max().tolist())
#MS1_pS1_IM_60min.iloc[0,:] = 0
#MS1_pS1_IM_60min.iloc[-1,:] = 0
MS1_pS1_IM_60min = MS1_pS1_IM_60min.reset_index()

# %%
MS1_pS2_IM_10min = MS1_pS2_IM_10min[(MS1_pS2_IM_10min.iloc[:,0] >= 0.96)&(MS1_pS2_IM_10min.iloc[:,0]<=1.08)]
MS1_pS2_IM_10min = MS1_pS2_IM_10min.iloc[:,[0,1,3,5]]
MS1_pS2_IM_10min.columns = ['Time','M','M+1','M+2']
MS1_pS2_IM_10min = MS1_pS2_IM_10min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS2_IM_10min = MS1_pS2_IM_10min - np.amin(MS1_pS2_IM_10min.min().tolist())
#MS1_pS2_IM_10min = MS1_pS2_IM_10min/np.amax(MS1_pS2_IM_10min.max().tolist())
MS1_pS2_IM_10min = MS1_pS2_IM_10min.reset_index()

# %%
MS1_pS2_IM_21min = MS1_pS2_IM_21min[(MS1_pS2_IM_21min.iloc[:,0] >= 0.96)&(MS1_pS2_IM_21min.iloc[:,0]<=1.08)]
MS1_pS2_IM_21min = MS1_pS2_IM_21min.iloc[:,[0,1,3,5]]
MS1_pS2_IM_21min.columns = ['Time','M','M+1','M+2']
MS1_pS2_IM_21min = MS1_pS2_IM_21min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS2_IM_21min = MS1_pS2_IM_21min - np.amin(MS1_pS2_IM_21min.min().tolist())
#MS1_pS2_IM_21min = MS1_pS2_IM_21min/np.amax(MS1_pS2_IM_21min.max().tolist())
#MS1_pS2_IM_21min.iloc[0,:] = 0
#MS1_pS2_IM_21min.iloc[-1,:] = 0
MS1_pS2_IM_21min = MS1_pS2_IM_21min.reset_index()

# %%
MS1_pS2_IM_60min = MS1_pS2_IM_60min[(MS1_pS2_IM_60min.iloc[:,0] >= 0.96)&(MS1_pS2_IM_60min.iloc[:,0]<=1.08)]
MS1_pS2_IM_60min = MS1_pS2_IM_60min.iloc[:,[0,1,3,5]]
MS1_pS2_IM_60min.columns = ['Time','M','M+1','M+2']
MS1_pS2_IM_60min = MS1_pS2_IM_60min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS2_IM_60min = MS1_pS2_IM_60min - np.amin(MS1_pS2_IM_60min.min().tolist())
#MS1_pS2_IM_60min = MS1_pS2_IM_60min/np.amax(MS1_pS2_IM_60min.max().tolist())
#MS1_pS2_IM_60min.iloc[0,:] = 0
#MS1_pS2_IM_60min.iloc[-1,:] = 0
MS1_pS2_IM_60min = MS1_pS2_IM_60min.reset_index()

# %%
MS1_pS2_XIC_10min = MS1_pS2_XIC_10min[(MS1_pS2_XIC_10min.iloc[:,0] >= 3.99)&(MS1_pS2_XIC_10min.iloc[:,0]<=4.39)]
MS1_pS2_XIC_10min = MS1_pS2_XIC_10min.iloc[:,[0,1,3,5]]
MS1_pS2_XIC_10min.columns = ['Time','M','M+1','M+2']
MS1_pS2_XIC_10min = MS1_pS2_XIC_10min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS2_XIC_10min = MS1_pS2_XIC_10min - np.amin(MS1_pS2_XIC_10min.min().tolist())
#MS1_pS2_XIC_10min = MS1_pS2_XIC_10min/np.amax(MS1_pS2_XIC_10min.max().tolist())
#MS1_pS2_XIC_10min.iloc[0,:] = 0
#MS1_pS2_XIC_10min.iloc[-1,:] = 0
MS1_pS2_XIC_10min = MS1_pS2_XIC_10min.reset_index()
MS1_pS2_XIC_10min = MS1_pS2_XIC_10min.iloc[2:,:]

# %%
MS1_pS1_XIC_10min = MS1_pS1_XIC_10min[(MS1_pS1_XIC_10min.iloc[:,0] >= 3.99)&(MS1_pS1_XIC_10min.iloc[:,0]<=4.39)]
MS1_pS1_XIC_10min = MS1_pS1_XIC_10min.iloc[:,[0,1,3,5]]
MS1_pS1_XIC_10min.columns = ['Time','M','M+1','M+2']
MS1_pS1_XIC_10min = MS1_pS1_XIC_10min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS1_XIC_10min = MS1_pS1_XIC_10min - np.amin(MS1_pS1_XIC_10min.min().tolist())
#MS1_pS1_XIC_10min = MS1_pS1_XIC_10min/np.amax(MS1_pS1_XIC_10min.max().tolist())
#MS1_pS1_XIC_10min.iloc[0,:] = 0
#MS1_pS1_XIC_10min.iloc[-1,:] = 0
MS1_pS1_XIC_10min = MS1_pS1_XIC_10min.reset_index()
MS1_pS1_XIC_10min = MS1_pS1_XIC_10min.iloc[[0,1,2],:]

# %%
MS1_pS1_XIC_21min = MS1_pS1_XIC_21min[(MS1_pS1_XIC_21min.iloc[:,0] >= 6.8)&(MS1_pS1_XIC_21min.iloc[:,0]<=7.2)]
MS1_pS1_XIC_21min = MS1_pS1_XIC_21min.iloc[:,[0,1,3,5]]
MS1_pS1_XIC_21min.columns = ['Time','M','M+1','M+2']
MS1_pS1_XIC_21min = MS1_pS1_XIC_21min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS1_XIC_21min = MS1_pS1_XIC_21min - np.amin(MS1_pS1_XIC_21min.min().tolist())
#MS1_pS1_XIC_21min = MS1_pS1_XIC_21min/np.amax(MS1_pS1_XIC_21min.max().tolist())
#MS1_pS1_XIC_21min.iloc[0,:] = 0
#MS1_pS1_XIC_21min.iloc[-1,:] = 0
MS1_pS1_XIC_21min = MS1_pS1_XIC_21min.reset_index()

# %%
MS1_pS2_XIC_21min = MS1_pS2_XIC_21min[(MS1_pS2_XIC_21min.iloc[:,0] >= 6.8)&(MS1_pS2_XIC_21min.iloc[:,0]<=7.2)]
MS1_pS2_XIC_21min = MS1_pS2_XIC_21min.iloc[:,[0,1,3,5]]
MS1_pS2_XIC_21min.columns = ['Time','M','M+1','M+2']
MS1_pS2_XIC_21min = MS1_pS2_XIC_21min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS2_XIC_21min = MS1_pS2_XIC_21min - np.amin(MS1_pS2_XIC_21min.min().tolist())
#MS1_pS2_XIC_21min = MS1_pS2_XIC_21min/np.amax(MS1_pS2_XIC_21min.max().tolist())
#MS1_pS2_XIC_21min.iloc[0,:] = 0
#MS1_pS2_XIC_21min.iloc[-1,:] = 0
MS1_pS2_XIC_21min = MS1_pS2_XIC_21min.reset_index()

# %%
MS1_pS1_XIC_60min = MS1_pS1_XIC_60min[(MS1_pS1_XIC_60min.iloc[:,0] >= 14.4)&(MS1_pS1_XIC_60min.iloc[:,0]<=15)]
MS1_pS1_XIC_60min = MS1_pS1_XIC_60min.iloc[:,[0,1,3,5]]
MS1_pS1_XIC_60min.columns = ['Time','M','M+1','M+2']
MS1_pS1_XIC_60min = MS1_pS1_XIC_60min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS1_XIC_60min = MS1_pS1_XIC_60min - np.amin(MS1_pS1_XIC_60min.min().tolist())
#MS1_pS1_XIC_60min = MS1_pS1_XIC_60min/np.amax(MS1_pS1_XIC_60min.max().tolist())
#MS1_pS1_XIC_60min.iloc[0,:] = 0
#MS1_pS1_XIC_60min.iloc[-1,:] = 0
MS1_pS1_XIC_60min = MS1_pS1_XIC_60min.reset_index()

# %%
MS1_pS2_XIC_60min = MS1_pS2_XIC_60min[(MS1_pS2_XIC_60min.iloc[:,0] >= 14.4)&(MS1_pS2_XIC_60min.iloc[:,0]<=15)]
MS1_pS2_XIC_60min = MS1_pS2_XIC_60min.iloc[:,[0,1,3,5]]
MS1_pS2_XIC_60min.columns = ['Time','M','M+1','M+2']
MS1_pS2_XIC_60min = MS1_pS2_XIC_60min.set_index('Time')
#MS1_pS1_IM_10min = MS1_pS1_IM_10min.reset_index()
#MS1_pS2_XIC_60min = MS1_pS2_XIC_60min - np.amin(MS1_pS2_XIC_60min.min().tolist())
#MS1_pS2_XIC_60min = MS1_pS2_XIC_60min/np.amax(MS1_pS2_XIC_60min.max().tolist())
#MS1_pS2_XIC_60min.iloc[0,:] = 0
#MS1_pS2_XIC_60min.iloc[-1,:] = 0
MS1_pS2_XIC_60min = MS1_pS2_XIC_60min.reset_index()

# %%
fig = make_subplots(rows = 3, cols = 2,shared_yaxes=True,
                    horizontal_spacing=0.08, vertical_spacing = 0.08)
#XIC pS1 10 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_10min.iloc[:,0], y = MS1_pS1_XIC_10min.iloc[:,1], mode = 'lines',
                         line_color = '#577BC1',
                        line = dict(width = 0.8)),
               row = 3, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_10min.iloc[:,0], y = MS1_pS1_XIC_10min.iloc[:,2], mode = 'lines',
                        line_color = '#344CB7',
                        line = dict(width = 0.8)), 
               row = 3, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_10min.iloc[:,0], y = MS1_pS1_XIC_10min.iloc[:,3], mode = 'lines',
                        line_color = '#000957',
                        line = dict(width = 0.8)), 
               row = 3, col = 1)
#XIC pS2 10 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_10min.iloc[:,0], y = MS1_pS2_XIC_10min.iloc[:,1], mode = 'lines',
                        line_color = '#E83A14',
                        line = dict(width = 0.8)), 
               row = 3, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_10min.iloc[:,0], y = MS1_pS2_XIC_10min.iloc[:,2], mode = 'lines',
                        line_color = '#890F0D',
                        line = dict(width = 0.8)), 
               row = 3, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_10min.iloc[:,0], y = MS1_pS2_XIC_10min.iloc[:,3], mode = 'lines',
                        line_color = '#630606',
                        line = dict(width = 0.8)), 
               row = 3, col = 1)
#IM pS1 10 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS1_IM_10min.iloc[:,0], y = MS1_pS1_IM_10min.iloc[:,1], mode = 'lines',
                        line_color = '#577BC1',
                        line = dict(width = 0.8)), 
               row = 3, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS1_IM_10min.iloc[:,0], y = MS1_pS1_IM_10min.iloc[:,2], mode = 'lines',
                        line_color = '#344CB7',
                        line = dict(width = 0.8)), 
               row = 3, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS1_IM_10min.iloc[:,0], y = MS1_pS1_IM_10min.iloc[:,3], mode = 'lines',
                        line_color = '#000957',
                        line = dict(width = 0.8)), 
               row = 3, col = 2)
#IM pS2 10 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS2_IM_10min.iloc[:,0], y = MS1_pS2_IM_10min.iloc[:,1], mode = 'lines',
                        line_color = '#E83A14',
                        line = dict(width = 0.8)), 
               row = 3, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS2_IM_10min.iloc[:,0], y = MS1_pS2_IM_10min.iloc[:,2], mode = 'lines',
                        line_color = '#890F0D',
                        line = dict(width = 0.8)), 
               row = 3, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS2_IM_10min.iloc[:,0], y = MS1_pS2_IM_10min.iloc[:,3], mode = 'lines',
                        line_color = '#630606',
                        line = dict(width = 0.8)), 
               row = 3, col = 2)
#########################
#########################
#XIC pS1 21 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_21min.iloc[:,0], y = MS1_pS1_XIC_21min.iloc[:,1], mode = 'lines',
                        line_color = '#577BC1',
                        line = dict(width = 0.8)),
               row = 2, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_21min.iloc[:,0], y = MS1_pS1_XIC_21min.iloc[:,2], mode = 'lines',
                        line_color = '#344CB7',
                        line = dict(width = 0.8)), 
               row = 2, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_21min.iloc[:,0], y = MS1_pS1_XIC_21min.iloc[:,3], mode = 'lines',
                        line_color = '#000957',
                        line = dict(width = 0.8)), 
               row = 2, col = 1)
#XIC pS2 21 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_21min.iloc[:,0], y = MS1_pS2_XIC_21min.iloc[:,1], mode = 'lines',
                        line_color = '#E83A14',
                        line = dict(width = 0.8)), 
               row = 2, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_21min.iloc[:,0], y = MS1_pS2_XIC_21min.iloc[:,2], mode = 'lines',
                        line_color = '#890F0D',
                        line = dict(width = 0.8)), 
               row = 2, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_21min.iloc[:,0], y = MS1_pS2_XIC_21min.iloc[:,3], mode = 'lines',
                        line_color = '#630606',
                        line = dict(width = 0.8)), 
               row = 2, col = 1)
#IM pS1 21 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS1_IM_21min.iloc[:,0], y = MS1_pS1_IM_21min.iloc[:,1], mode = 'lines',
                        line_color = '#577BC1',
                        line = dict(width = 0.8)), 
               row = 2, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS1_IM_21min.iloc[:,0], y = MS1_pS1_IM_21min.iloc[:,2], mode = 'lines',
                        line_color = '#344CB7',
                        line = dict(width = 0.8)), 
               row = 2, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS1_IM_21min.iloc[:,0], y = MS1_pS1_IM_21min.iloc[:,3], mode = 'lines',
                        line_color = '#000957',
                        line = dict(width = 0.8)), 
               row = 2, col = 2)
#IM pS2 21 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS2_IM_21min.iloc[:,0], y = MS1_pS2_IM_21min.iloc[:,1], mode = 'lines',
                        line_color = '#E83A14',
                        line = dict(width = 0.8)), 
               row = 2, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS2_IM_21min.iloc[:,0], y = MS1_pS2_IM_21min.iloc[:,2], mode = 'lines',
                        line_color = '#890F0D',
                        line = dict(width = 0.8)), 
               row = 2, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS2_IM_21min.iloc[:,0], y = MS1_pS2_IM_21min.iloc[:,3], mode = 'lines',
                        line_color = '#630606',
                        line = dict(width = 0.8)), 
               row = 2, col = 2)
###########################
###########################
#XIC pS1 60 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_60min.iloc[:,0], y = MS1_pS1_XIC_60min.iloc[:,1], mode = 'lines',
                        line_color = '#577BC1',
                        line = dict(width = 0.8)),
               row = 1, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_60min.iloc[:,0], y = MS1_pS1_XIC_60min.iloc[:,2], mode = 'lines',
                        line_color = '#344CB7',
                        line = dict(width = 0.8)), 
               row = 1, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS1_XIC_60min.iloc[:,0], y = MS1_pS1_XIC_60min.iloc[:,3], mode = 'lines',
                        line_color = '#000957',
                        line = dict(width = 0.8)), 
               row = 1, col = 1)
#XIC pS2 60 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_60min.iloc[:,0], y = MS1_pS2_XIC_60min.iloc[:,1], mode = 'lines',
                        line_color = '#E83A14',
                        line = dict(width = 0.8)), 
               row = 1, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_60min.iloc[:,0], y = MS1_pS2_XIC_60min.iloc[:,2], mode = 'lines',
                        line_color = '#890F0D',
                        line = dict(width = 0.8)), 
               row = 1, col = 1)
fig.add_trace(go.Scatter(x = MS1_pS2_XIC_60min.iloc[:,0], y = MS1_pS2_XIC_60min.iloc[:,3], mode = 'lines',
                        line_color = '#630606',
                        line = dict(width = 0.8)), 
               row = 1, col = 1)
#IM pS1 60 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS1_IM_60min.iloc[:,0], y = MS1_pS1_IM_60min.iloc[:,1], mode = 'lines',
                        line_color = '#577BC1',
                        line = dict(width = 0.8)), 
               row = 1, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS1_IM_60min.iloc[:,0], y = MS1_pS1_IM_60min.iloc[:,2], mode = 'lines',
                        line_color = '#344CB7',
                        line = dict(width = 0.8)), 
               row = 1, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS1_IM_60min.iloc[:,0], y = MS1_pS1_IM_60min.iloc[:,3], mode = 'lines',
                        line_color = '#000957',
                        line = dict(width = 0.8)), 
               row = 1, col = 2)
#IM pS2 60 min gradient time
fig.add_trace(go.Scatter(x = MS1_pS2_IM_60min.iloc[:,0], y = MS1_pS2_IM_60min.iloc[:,1], mode = 'lines',
                        line_color = '#E83A14',
                        line = dict(width = 0.8)), 
               row = 1, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS2_IM_60min.iloc[:,0], y = MS1_pS2_IM_60min.iloc[:,2], mode = 'lines',
                        line_color = '#890F0D',
                        line = dict(width = 0.8)), 
               row = 1, col = 2)
fig.add_trace(go.Scatter(x = MS1_pS2_IM_60min.iloc[:,0], y = MS1_pS2_IM_60min.iloc[:,3], mode = 'lines',
                        line_color = '#630606',
                        line = dict(width = 0.8)), 
               row = 1, col = 2)
fig.update_layout(template = 'simple_white', width = 566.929133865, height = 566.929133865, showlegend = False, 
                  xaxis2 = dict(range=[0.96, 1.08], showticklabels = False),
                 xaxis1 = dict(range=[14.4, 15]),
                 xaxis3 = dict(range=[6.8, 7.2]),
                 xaxis4 = dict(range=[0.96, 1.08],showticklabels = False),
                 xaxis6 = dict(range=[0.96, 1.08]),
                 xaxis5 = dict(range=[3.99, 4.39]),
                 xaxis5_title = 'Gradient time, min',
                 xaxis6_title = 'Ion mobility, 1/K₀')
fig.update_yaxes(title_font=dict(size=12, family='Arial', color='black'),
                tickfont = dict(
      family = 'Arial',
      size = 12,
      color = 'black'
      ))
fig.update_xaxes(title_font=dict(size=12, family='Arial', color='black'),
                tickfont = dict(
      family = 'Arial',
      size = 12,
      color = 'black'
      ))
#fig.write_image('fig4C_mod.pdf')
# Out:
# <div>                            <div id="2c02d997-0ff4-4b07-9d95-b745b4692fa4" class="plotly-graph-div" style="height:566.929133865px; width:566.929133865px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c02d997-0ff4-4b07-9d95-b745b4692fa4")) {                    Plotly.newPlot(                        "2c02d997-0ff4-4b07-9d95-b745b4692fa4",                        [{"line":{"color":"#577BC1","width":0.8},"mode":"lines","x":[4.00759220123291,4.03056001663208,4.0535306930542],"y":[0.358581334352493,0.94847583770752,0.137398064136505],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#344CB7","width":0.8},"mode":"lines","x":[4.00759220123291,4.03056001663208,4.0535306930542],"y":[0.652325212955475,65.0,0.0665991455316544],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#000957","w
# ...

# %%
t_rt = [313, 375, 438, 442, 412, 414]
t_IM = [101, 116, 116, 137, 122, 135]
grad = ['7 min', '10 min','15 min','21 min','30 min','60 min']
df = pd.DataFrame({'Ret':t_rt, 'IM':t_IM, 'ID':grad})

# %%
fig = go.Figure([go.Bar(x = df['ID'], y = df['Ret'], text = df['Ret'])])
fig.update_layout(template = 'simple_white', width = 377.95275591, height = 377.95275591)
fig.update_yaxes(showgrid = True)
fig.update_xaxes(title_font=dict(size=10, family='Arial', color='black'),
                tickfont = dict(
      family = 'Arial',
      size = 10,
      color = 'black'
      ))
fig.update_traces(marker_color='#22577E', marker_line_color='black',
                  marker_line_width=1.5, opacity=1)
fig.write_image('fig4A.pdf')

# %%
fig = go.Figure([go.Bar(x = df['ID'], y = df['IM'], text = df['IM'])])
fig.update_layout(template = 'simple_white', width = 377.95275591, height = 377.95275591)
fig.update_yaxes(showgrid = True)
fig.update_xaxes(title_font=dict(size=10, family='Arial', color='black'),
                tickfont = dict(
      family = 'Arial',
      size = 10,
      color = 'black'
      ))
fig.update_traces(marker_color='#890F0D', marker_line_color='black',
                  marker_line_width=1.5, opacity=1)
fig.write_image('fig4B.pdf')
